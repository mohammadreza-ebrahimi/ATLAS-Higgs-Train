# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C://Users/Al-Mahdi/Desktop/MLHEP/higgs-boson/training.csv')

# %%
df.head()
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002      -999.000                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  ...  PRI_jet_num  PRI_jet_leading_pt  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   EventId                      250000 non-null  int64
#  1   DER_mass_MMC                 250000 non-null  float64
#  2   DER_mass_transverse_met_lep  250000 non-null  float64
#  3   DER_mass_vis                 250000 non-null  float64
#  4   DER_pt_h                     250000 non-null  float64
#  5   DER_deltaeta_jet_jet         250000 non-null  float64
#  6   DER_mass_jet_jet             250000 non-null  float64
#  7   DER_prodeta_jet_jet          250000 non-null  float64
#  8   DER_deltar_tau_lep           250000 non-null  float64
#  9   DER_pt_tot                   250000 non-null  float64
#  10  DER_sum_pt                   250000 non-null  float64
#  11  DER_pt_ratio_lep_tau         250000 non-null  float64
# ...

# %%
df.describe()
# Out:
#              EventId   DER_mass_MMC  DER_mass_transverse_met_lep  \
# count  250000.000000  250000.000000                250000.000000
# mean   224999.500000     -49.023079                    49.239819
# std     72168.927986     406.345647                    35.344886
# min    100000.000000    -999.000000                     0.000000
# 25%    162499.750000      78.100750                    19.241000
# 50%    224999.500000     105.012000                    46.524000
# 75%    287499.250000     130.606250                    73.598000
# max    349999.000000    1192.026000                   690.075000
#
#         DER_mass_vis       DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  250000.000000  250000.000000         250000.000000     250000.000000
# mean       81.181982      57.895962           -708.420675       -601.237051
# std        40.828691      63.655682            454.480565        657.972302
# ...

# %%
df.isnull().sum()
# Out:
# EventId                        0
# DER_mass_MMC                   0
# DER_mass_transverse_met_lep    0
# DER_mass_vis                   0
# DER_pt_h                       0
# DER_deltaeta_jet_jet           0
# DER_mass_jet_jet               0
# DER_prodeta_jet_jet            0
# DER_deltar_tau_lep             0
# DER_pt_tot                     0
# DER_sum_pt                     0
# DER_pt_ratio_lep_tau           0
# DER_met_phi_centrality         0
# DER_lep_eta_centrality         0
# PRI_tau_pt                     0
# PRI_tau_eta                    0
# PRI_tau_phi                    0
# PRI_lep_pt                     0
# PRI_lep_eta                    0
# PRI_lep_phi                    0
# PRI_met                        0
# PRI_met_phi                    0
# PRI_met_sumet                  0
# PRI_jet_num                    0
# PRI_jet_leading_pt             0
# PRI_jet_leading_eta            0
# PRI_jet_leading_phi            0
# PRI_jet_subleading_pt          0
# ...

# %%
df.hist(bins=50, figsize=(30, 25))
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df['Labels']=label.fit_transform(df['Label'])
df.drop('Label', axis=1, inplace=True)

# %%
df['Labels']
#s=1 , b=1
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 249995    0
# 249996    0
# 249997    1
# 249998    0
# 249999    0
# Name: Labels, Length: 250000, dtype: int32

# %%
corr_mx=df.corr()
print(corr_mx['Labels'].sort_values(ascending=False))
# Out:
# Labels                         1.000000
# DER_met_phi_centrality         0.271752
# DER_mass_MMC                   0.239149
# PRI_tau_pt                     0.235238
# DER_pt_h                       0.192526
# DER_mass_jet_jet               0.191766
# PRI_jet_leading_pt             0.157604
# DER_sum_pt                     0.153236
# PRI_jet_leading_eta            0.150469
# PRI_jet_leading_phi            0.150468
# DER_deltaeta_jet_jet           0.141646
# DER_lep_eta_centrality         0.141346
# PRI_jet_subleading_eta         0.141265
# PRI_jet_subleading_phi         0.141256
# PRI_jet_subleading_pt          0.140714
# DER_prodeta_jet_jet            0.140554
# PRI_met_sumet                  0.135520
# PRI_jet_all_pt                 0.134296
# PRI_jet_num                    0.133549
# PRI_met                        0.022466
# DER_deltar_tau_lep             0.012245
# PRI_met_phi                    0.007475
# PRI_lep_phi                    0.004125
# ...

# %%
#Let's drop some useless data 
df.drop(columns=['EventId','PRI_lep_eta','PRI_tau_eta','PRI_tau_phi'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis',
#        'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet',
#        'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt',
#        'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality',
#        'DER_lep_eta_centrality', 'PRI_tau_pt', 'PRI_lep_pt', 'PRI_lep_phi',
#        'PRI_met', 'PRI_met_phi', 'PRI_met_sumet', 'PRI_jet_num',
#        'PRI_jet_leading_pt', 'PRI_jet_leading_eta', 'PRI_jet_leading_phi',
#        'PRI_jet_subleading_pt', 'PRI_jet_subleading_eta',
#        'PRI_jet_subleading_phi', 'PRI_jet_all_pt', 'Weight', 'Label'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   DER_mass_MMC                 250000 non-null  float64
#  1   DER_mass_transverse_met_lep  250000 non-null  float64
#  2   DER_mass_vis                 250000 non-null  float64
#  3   DER_pt_h                     250000 non-null  float64
#  4   DER_deltaeta_jet_jet         250000 non-null  float64
#  5   DER_mass_jet_jet             250000 non-null  float64
#  6   DER_prodeta_jet_jet          250000 non-null  float64
#  7   DER_deltar_tau_lep           250000 non-null  float64
#  8   DER_pt_tot                   250000 non-null  float64
#  9   DER_sum_pt                   250000 non-null  float64
#  10  DER_pt_ratio_lep_tau         250000 non-null  float64
#  11  DER_met_phi_centrality       250000 non-null  float64
# ...

# %%
import seaborn as sns

data= df[df.columns[1:28]]

for i in range(0, data.shape[1]):
    plt.figure()
    sns.distplot(data.iloc[:, i], bins=40,color="r")
    
plt.show()
# Out:
# E:\New folder\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\New folder\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
X_train=df.drop('Labels', axis=1, inplace=False)
y_train=df['Labels'].copy()

# %%
y_train
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 249995    0
# 249996    0
# 249997    1
# 249998    0
# 249999    0
# Name: Labels, Length: 250000, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, roc_auc_score
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_predict, cross_val_score, GridSearchCV

# %%
result_tab=pd.DataFrame({
    'Model':[],
    'Accuracy':[],
    'Recall score':[],
    'Precision score':[],
    'F1 score':[],
    'ROC_AUC score':[],
})
result_tab.shape
# Out:
# (0, 6)

# %%
def model_train(model, X, y, cv=10):
    model.fit(X, y)
    model_score=cross_val_predict(model, X, y, cv=cv)
    acc=accuracy_score(model_score, y_train)
    recall=recall_score(model_score, y_train)
    prec=precision_score(model_score, y_train)
    f1=f1_score(model_score, y_train)
    roc=roc_auc_score(model_score, y_train)
    
    row=result_tab.shape[0]
    result_tab.loc[row]=['%s' %model, acc, recall, prec, f1, roc]
    
    return result_tab

# %%
scale=StandardScaler()
X_train_scale=scale.fit_transform(X_train)

# %%
log_reg=LogisticRegression(penalty='none', max_iter=200, C=5)
model_train(log_reg, X_train_scale, y_train)
# Out:
# E:\New folder\python\lib\site-packages\sklearn\linear_model\_logistic.py:1320: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# E:\New folder\python\lib\site-packages\sklearn\linear_model\_logistic.py:1320: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# E:\New folder\python\lib\site-packages\sklearn\linear_model\_logistic.py:1320: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# E:\New folder\python\lib\site-packages\sklearn\linear_model\_logistic.py:1320: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# E:\New folder\python\lib\site-packages\sklearn\linear_model\_logistic.py:1320: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
knn=KNeighborsClassifier(n_neighbors=2)
model_train(knn, X_train_scale, y_train)
# Out:
#                                                Model  Accuracy  Recall score  \
# 0  LogisticRegression(C=5, max_iter=200, penalty=...  0.999996       1.00000
# 1                KNeighborsClassifier(n_neighbors=2)  0.888620       0.89641
#
#    Precision score  F1 score  ROC_AUC score
# 0         0.999988  0.999994       0.999997
# 1         0.763153  0.824431       0.890911

# %%
tree=DecisionTreeClassifier()
model_train(tree, X_train_scale, y_train)
# Out:
#                                                Model  Accuracy  Recall score  \
# 0  LogisticRegression(C=5, max_iter=200, penalty=...  0.999996       1.00000
# 1                KNeighborsClassifier(n_neighbors=2)  0.888620       0.89641
# 2                           DecisionTreeClassifier()  1.000000       1.00000
#
#    Precision score  F1 score  ROC_AUC score
# 0         0.999988  0.999994       0.999997
# 1         0.763153  0.824431       0.890911
# 2         1.000000  1.000000       1.000000

# %%
random_forest=RandomForestClassifier()
model_train(random_forest, X_train_scale, y_train)
# Out:
#                                                Model  Accuracy  Recall score  \
# 0  LogisticRegression(C=5, max_iter=200, penalty=...  0.999996       1.00000
# 1                KNeighborsClassifier(n_neighbors=2)  0.888620       0.89641
# 2                           DecisionTreeClassifier()  1.000000       1.00000
# 3                           RandomForestClassifier()  1.000000       1.00000
#
#    Precision score  F1 score  ROC_AUC score
# 0         0.999988  0.999994       0.999997
# 1         0.763153  0.824431       0.890911
# 2         1.000000  1.000000       1.000000
# 3         1.000000  1.000000       1.000000

# %%
sgd=SGDClassifier()
model_train(sgd, X_train_scale, y_train)
# Out:
#                                                Model  Accuracy  Recall score  \
# 0  LogisticRegression(C=5, max_iter=200, penalty=...  0.999996      1.000000
# 1                KNeighborsClassifier(n_neighbors=2)  0.888620      0.896410
# 2                           DecisionTreeClassifier()  1.000000      1.000000
# 3                           RandomForestClassifier()  1.000000      1.000000
# 4                                    SGDClassifier()  0.970532      0.923289
#
#    Precision score  F1 score  ROC_AUC score
# 0         0.999988  0.999994       0.999997
# 1         0.763153  0.824431       0.890911
# 2         1.000000  1.000000       1.000000
# 3         1.000000  1.000000       1.000000
# 4         0.996825  0.958649       0.960781

# %%
from sklearn.svm import SVC, LinearSVC

lin_scv=LinearSVC(C=10 ,max_iter=1000, random_state=42, loss='hinge')
model_train(lin_scv, X_train_scale, y_train)
# Out:
# E:\New folder\python\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# E:\New folder\python\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# E:\New folder\python\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# E:\New folder\python\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# E:\New folder\python\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
# ...

# %%
#svc_rbf=SVC(kernel='rbf', C=100, gamma=0.03, random_state=42)
#model_train(svc_rbf, X_train, y_train)

# %%
df_test=pd.read_csv('C://Users/Al-Mahdi/Desktop/MLHEP/higgs-boson/test.csv')
#df_test['Labels']=label.fit(df_test['Label'])
#df_test.drop('Label', axis=1, inplace=True)

# %%
df_test
# Out:
#         EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0        350000      -999.000                       79.589        23.916
# 1        350001       106.398                       67.490        87.949
# 2        350002       117.794                       56.226        96.358
# 3        350003       135.861                       30.604        97.288
# 4        350004        74.159                       82.772        58.731
# ...         ...           ...                          ...           ...
# 549995   899995       309.530                       28.185       170.795
# 549996   899996       105.653                        5.096        77.256
# 549997   899997      -999.000                       69.470        51.766
# 549998   899998       107.254                       13.500        79.833
# 549999   899999       107.961                       85.200        75.670
#
#         DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550000 entries, 0 to 549999
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   EventId                      550000 non-null  int64
#  1   DER_mass_MMC                 550000 non-null  float64
#  2   DER_mass_transverse_met_lep  550000 non-null  float64
#  3   DER_mass_vis                 550000 non-null  float64
#  4   DER_pt_h                     550000 non-null  float64
#  5   DER_deltaeta_jet_jet         550000 non-null  float64
#  6   DER_mass_jet_jet             550000 non-null  float64
#  7   DER_prodeta_jet_jet          550000 non-null  float64
#  8   DER_deltar_tau_lep           550000 non-null  float64
#  9   DER_pt_tot                   550000 non-null  float64
#  10  DER_sum_pt                   550000 non-null  float64
#  11  DER_pt_ratio_lep_tau         550000 non-null  float64
# ...

# %%
df_test.drop('EventId', axis=1, inplace=True)

# %%
def plot_clusters(X, y):

    # Create an figure with a custom size
    # plt.figure(figsize=(6, 4))
    
    if y is not None:
        for cluster_label in np.unique(y):
            # Plot all objects with y == i (class 0)
            plt.scatter(X[(y == cluster_label).astype(int), 0],     # selects all objects with y == i and the 1st column of X
                        X[(y == cluster_label).astype(int), 1],     # selects all objects with y == i and the 2nd column of X
                        label=str(cluster_label))     # label for the plot legend
    else:
        plt.scatter(X[:, 0], X[:, 1], label='samples')

    plt.xlabel('X1', size=12) # set up X-axis label
    plt.ylabel('X2', size=12) # set up Y-axis label
    plt.xticks(size=12)
    plt.yticks(size=12)

    plt.legend(loc='best', fontsize=12) # create the plot legend and set up it position
    plt.grid(b=1) # create grid on the plot

    plt.show() # display the plot

# %%
from sklearn.cluster import DBSCAN

# run clusterer
clusterer = DBSCAN(eps=0.15, min_samples=2)
y_pred = clusterer.fit_predict(df_test)

# plot clustering results
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-57bd10b1c694> in <module>
#       6
#       7 # plot clustering results
# ----> 8 plot_clusters(df_test, y_pred)
#
# <ipython-input-7-090217b5b74f> in plot_clusters(X, y)
#       7         for cluster_label in np.unique(y):
#       8             # Plot all objects with y == i (class 0)
# ----> 9             plt.scatter(X[y == cluster_label, 0],     # selects all objects with y == i and the 1st column of X
#      10                         X[y == cluster_label, 1],     # selects all objects with y == i and the 2nd column of X
#      11                         label=str(cluster_label))     # label for the plot legend
#
# E:\New folder\python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
# ...

# %%
from sklearn.cluster import KMeans


kmeans_clus=KMeans(n_clusters=2) #Build an instance of model
kmeans_tr=kmeans_clus.fit_transform(df_test)
